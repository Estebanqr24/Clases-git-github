# %%
print("hola mundo")
# Out:
# hola mundo

# %%
print (" no sé xq no funciona la situación de la función")
# Out:
#  no sé xq no funciona la situación de la función

# %%
print ("ahora será ssh?")
# Out:
# ahora será ssh?

# %%
print ("ya son las cinco d el amñana putamare")
# Out:
# ya son las cinco d el amñana putamare

# %%
print ("tmr ya es demasiado tarde para hacer algo")
# Out:
# tmr ya es demasiado tarde para hacer algo

# %%
print (" que ha pasado")
# Out:
#  que ha pasado
